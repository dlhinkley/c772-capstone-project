# %% [markdown]
# # Data Exploration

# %%
# %run "./C772 Capstone Initialization Sub-Notebook"

# %%
# %run "./C772 Capstone Summarization Sub-Notebook"

# %%
# %run "./C772 Capstone Investigation Sub-Notebook"

# %%
# %run "./C772 Capstone Cleaning Sub-Notebook"

# %%
# %run "./C772 Capstone Aggregation Sub-Notebook"
