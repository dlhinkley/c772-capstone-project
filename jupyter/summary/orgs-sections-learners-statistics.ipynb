# %% [markdown]
# ### Org, Sections, Learners, Statistics

# %%
# %%capture

# %run '../lib/libraries.ipynb'
from ..lib import utilities as util

# %%
filterDf  = util.load_df('filterDf')
descDf = util.load_df('descDf')
types = util.get_var_types()

# %% [markdown]
# ##### Num Sections by Organization

# %%
util.num_sections_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Num Learners by Organization

# %%
util.num_learners_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Section Learners by Organization

# %%
util.mean_sec_learners_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Section Assessments by Organization

# %%
util.mean_sec_assess_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Learners Assessments by Organization

# %%
util.mean_assess_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Scores by Organization

# %%
util.mean_scores_by_orgs_bar_chart(filterDf)
