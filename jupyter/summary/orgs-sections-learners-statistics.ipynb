# %% [markdown]
# ### Org, Sections, Learners, Statistics

# %%
# %run '../lib/libraries.ipynb'
# Out:
# dython              0.6.1
# tinydb              4.2.0
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the '/Users/duane.hinkley/PycharmProjects/c772-capstone-project/venv/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the '/Users/duane.hinkley/PycharmProjects/c772-capstone-project/venv/bin/python -m pip install --upgrade pip' command.

# %%
filterDf  = load_df('filterDf')
descDf = load_df('descDf')
types = get_var_types()

# %% [markdown]
# ##### Num Sections by Organization

# %%
num_sections_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Num Learners by Organization

# %%
num_learners_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Section Learners by Organization

# %%
mean_sec_learners_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Section Assessments by Organization

# %%
mean_sec_assess_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Learners Assessments by Organization

# %%
mean_assess_by_org_bar_chart(filterDf)

# %% [markdown]
# ##### Mean Scores by Organization

# %%
mean_scores_by_orgs_bar_chart(filterDf)
