# %% [markdown]
# ### Investigate [unassigned] in scoring_type_code

# %%
# %%capture

# %run '../lib/libraries.ipynb'

# %%
filterDf  = load_df('filterDf')

# %% [markdown]
# ###### Create Dataframe of null observations

# %%
invDf = filterDf.filter(F.col('scoring_type_code') == '[unassigned]')

invDf.count()
# Out:
# 1600

# %% [markdown]
# 1,600 null observations

# %% [markdown]
# ###### Display distinct values

# %%
distinct_val(invDf)
# Out:
#                                             0
# is_force_scored (aa)                    False
# is_manual_scoring_required (aa)         False
# item_is_offline_scored (i)              False
# scoring_type_code (i)            [unassigned]

# %% [markdown]
# - No new information

# %% [markdown]
# ###### Compare dates with full sample

# %%
dual_date_boxplot(
    get_random_sample(filterDf),
    invDf,
    title1="All Dates",
    title2='Null Dates',
    main='All vs Null Dates'
)

# %% [markdown]
# - Assignment scheduled between 10/20 and 11/10
#     - assignment_due_date
#     - assignment_final_submission_date
#     - assignment_start_date

# %% [markdown]
# ###### Conclusion
#
# - Impacts a short period
# - Variable will not be used
#   - no further action needed

# %%
finish_todo('Investigate [unassigned] in scoring_type_code')
# Out:
# Finished: Investigate [unassigned] in scoring_type_code
