# %% [markdown]
# ### Investigate [unassigned] in response_correctness

# %%
# %%capture

# %run '../lib/libraries.ipynb'

# %%
filterDf = load_df('filterDf')

# %% [markdown]
# ###### Select the  1566 unassigned values in response_correctness

# %%
dfUnassigned = filterDf.filter( F.col('response_correctness') == '[unassigned]' )
dfUnassigned.count()
# Out:
# 1566

# %% [markdown]
# ###### Display Distinct Values

# %%
distinct_val(dfUnassigned)
# Out:
#                                                  0
# assigned_item_status (ia)                   scored
# assignment_attempt_number (aa)                   0
# assignment_due_date (a)                        NaT
# assignment_final_submission_date (a)           NaT
# assignment_max_attempts (a)                      0
# assignment_start_date (a)                      NaT
# is_affecting_grade (a)                        True
# is_force_scored (aa)                         False
# is_manual_scoring_required (aa)              False
# item_is_offline_scored (i)                   False
# org_id (o)                                  117713
# response_correctness (ia)             [unassigned]
# scoring_type_code (i)                 [unassigned]
# timeliness_duration_mins (aa)                  NaN

# %% [markdown]
# - Null Assignment Dates
#   - assignment_due_date
#   - assignment_final_submission_date
#   - assignment_start_date
# - On organization
# - Not scored
#   - scoring_type_code = [unassigned]

# %% [markdown]
# ###### Display Interval Statistics for null and all

# %%
dual_date_boxplot(
    get_random_sample(filterDf),
    dfUnassigned,
    title1='All',
    title2='Unassigned',
    main='All and After Unassigned Dates'
)

# %% [markdown]
# - Null
#   - assignement_due_date (a)
#   - assignement_final_submission_date (a)
#   - assignment_start_date (a)
# - Has scored dates
# - Has item attempt dates

# %% [markdown]
# ###### Conclusion: 1566 [unassigned] in response_correctness
# - Only using scored items
#   - Remove values

# %% [markdown]
# ###### Test Removal

# %%
filterDf.count() - remove_unassigned_response_correctness(filterDf).count()
# Out:
# 1566

# %% [markdown]
# - 1566 removed

# %%
finish_todo("Investigate [unassigned] in response_correctness")
add_todo("Remove [unassigned] in response_correctness")
finish_todo('Investigate assignment_attempt_number and assignment_max_attempts both have 1566 values')
# Out:
# Finished: Investigate [unassigned] in response_correctness
# Todo: Remove [unassigned] in response_correctness
# Finished: Investigate assignment_attempt_number and assignment_max_attempts both have 1566 values
